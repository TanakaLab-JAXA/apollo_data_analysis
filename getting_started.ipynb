# %% [markdown]
# # Sample

# %% [markdown]
# ### Import methods

# %%
import src.MQPlots as plots
import src.MQUtils as utils
from src.MQData import MQData
from src.MQData import read_raw

# %% [markdown]
# ### Get data

# %%
mq = MQData()
read_raw(
    mq,
    path="http://darts.isas.jaxa.jp/pub/apollo/pse/p14s/pse.a14.1.156",
    station_number=14,
)

# %% [markdown]
# ### Plots + Preprocessing

# %%
plots.plot_du(mq=mq, channel="SPZ")

# %%
utils.remove_noise(mq=mq, channel="SPZ", times=10)
# Out:
# array([1.79069856, 1.79074652, 1.79077915, ..., 1.70352092, 1.70230233,
#        1.7016266 ])

# %%
plots.plot_comparison_with_du(mq=mq, channel="SPZ", is_du_detrend=True)

# %%
utils.du2phys(mq=mq, channel="SPZ")

# %%
plots.plot_comparison_with_du(mq=mq, channel="SPZ", is_du_detrend=True, is_phys=True)

# %%
plots.plot_spectrogram(mq=mq, channel="SPZ")
